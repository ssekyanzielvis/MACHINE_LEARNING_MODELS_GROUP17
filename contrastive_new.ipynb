# %%
import pandas as pd
import numpy as np
from scipy.signal import find_peaks
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers
from sklearn.model_selection import train_test_split
from sklearn.cluster import KMeans
from sklearn.metrics import accuracy_score

# --- 1. Data Loading and Preprocessing ---
def load_and_preprocess(data_path):
    df = pd.read_csv(data_path)
    peaks, _ = find_peaks(df["MLII"], distance=150)
    heartbeats = []
    for peak in peaks:
        start = max(0, peak - 150)
        end = min(len(df), peak + 150)
        heartbeat = df["MLII"][start:end].values
        if len(heartbeat) == 300:
            heartbeats.append(heartbeat)
    heartbeats = np.array(heartbeats).reshape(-1, 300, 1)
    return heartbeats

def augment(heartbeat):
    noise = np.random.normal(0, 0.01, heartbeat.shape)
    time_shift = np.random.randint(-10, 10)
    augmented = tf.roll(heartbeat + noise, shift=time_shift, axis=0)
    return augmented

data_path = "C:/Users/abdulssekyanzi/EDA Dataset.csv/100.csv" #replace
heartbeats = load_and_preprocess(data_path)

# --- 2. Model Architecture ---
def create_encoder(input_shape):
    model = models.Sequential([
        layers.Conv1D(64, 5, activation="relu", input_shape=input_shape),
        layers.MaxPooling1D(2),
        layers.Conv1D(128, 3, activation="relu"),
        layers.GlobalAveragePooling1D(),
        layers.Dense(128),
    ])
    return model

encoder = create_encoder((300, 1))

# NT-Xent Loss
def nt_xent_loss(embeddings, temperature=0.1):
    batch_size = tf.shape(embeddings)[0] // 2
    embeddings_a = embeddings[:batch_size]
    embeddings_b = embeddings[batch_size:]
    normalized_embeddings_a = tf.nn.l2_normalize(embeddings_a, axis=1)
    normalized_embeddings_b = tf.nn.l2_normalize(embeddings_b, axis=1)
    logits = tf.matmul(normalized_embeddings_a, tf.transpose(normalized_embeddings_b)) / temperature
    labels = tf.range(batch_size)
    loss_a = tf.keras.losses.sparse_categorical_crossentropy(labels, logits, from_logits=True)
    loss_b = tf.keras.losses.sparse_categorical_crossentropy(labels, tf.transpose(logits), from_logits=True)
    return (tf.reduce_mean(loss_a) + tf.reduce_mean(loss_b)) / 2

# --- 3. Training (Contrastive) ---
optimizer = optimizers.Adam(0.001)

@tf.function
def train_step(heartbeats_list):
    augmented_heartbeats_a = tf.stack([augment(hb) for hb in heartbeats_list])
    augmented_heartbeats_b = tf.stack([augment(hb) for hb in heartbeats_list])
    with tf.GradientTape() as tape:
        embeddings_a = encoder(augmented_heartbeats_a, training=True)
        embeddings_b = encoder(augmented_heartbeats_b, training=True)
        embeddings = tf.concat([embeddings_a, embeddings_b], axis=0)
        loss = nt_xent_loss(embeddings)
    gradients = tape.gradient(loss, encoder.trainable_variables)
    optimizer.apply_gradients(zip(gradients, encoder.trainable_variables))
    return loss

epochs_contrastive = 50
batch_size = 32
for epoch in range(epochs_contrastive):
    for i in range(0, len(heartbeats), batch_size):
        batch = heartbeats[i:i + batch_size]
        loss = train_step(list(batch))
    print(f"Contrastive Epoch {epoch + 1}, Loss: {loss.numpy()}")

# --- 4. Pseudo-Labeling (Clustering) ---
embeddings = encoder.predict(heartbeats)
kmeans = KMeans(n_clusters=4, random_state=42) #Adjust number of clusters
pseudo_labels = kmeans.fit_predict(embeddings)

# --- 5. Supervised Fine-tuning (with Pseudo-Labels) ---
X_train_pseudo, X_test_pseudo, y_train_pseudo, y_test_pseudo = train_test_split(heartbeats, pseudo_labels, test_size=0.2, random_state=42)

classification_head = models.Sequential([
    encoder,
    layers.Dense(len(np.unique(pseudo_labels)), activation="softmax")
])
classification_head.compile(optimizer=optimizers.Adam(0.001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

epochs_finetune = 30
classification_history = classification_head.fit(X_train_pseudo, y_train_pseudo, epochs=epochs_finetune, batch_size=32, validation_split=0.2)

# --- 6. Evaluation ---
loss, accuracy = classification_head.evaluate(X_test_pseudo, y_test_pseudo)
print(f"Pseudo-Test Accuracy: {accuracy}")
import pickle

# Assuming `Contrastive` is your trained machine learning model
with open('contrastive_new.pkl', 'wb') as file:
    pickle.dump(Contrastive, file)
# Out:
# C:\Users\abdulssekyanzi\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Contrastive Epoch 1, Loss: 1.2971758842468262
# Contrastive Epoch 2, Loss: 1.2793577909469604
# Contrastive Epoch 3, Loss: 1.2103981971740723
# Contrastive Epoch 4, Loss: 1.161797046661377
# Contrastive Epoch 5, Loss: 1.22334623336792
# Contrastive Epoch 6, Loss: 1.1572153568267822
# Contrastive Epoch 7, Loss: 1.1240514516830444
# Contrastive Epoch 8, Loss: 1.0323011875152588
# Contrastive Epoch 9, Loss: 0.9670186042785645
# Contrastive Epoch 10, Loss: 0.9370958805084229
# Contrastive Epoch 11, Loss: 0.9415258169174194
# Contrastive Epoch 12, Loss: 0.9420788288116455
# Contrastive Epoch 13, Loss: 0.9122030138969421
# Contrastive Epoch 14, Loss: 0.8657336235046387
# Contrastive Epoch 15, Loss: 0.8368385434150696
# Contrastive Epoch 16, Loss: 0.7614505887031555
# Contrastive Epoch 17, Loss: 0.7314350008964539
# Contrastive Epoch 18, Loss: 0.7150031924247742
# Contrastive Epoch 19, Loss: 0.706174910068512
# Contrastive Epoch 20, Loss: 0.6742541790008545
# Contrastive Epoch 21, Loss: 0.6208217144012451
# Contrastive Epoch 22, Loss: 0.5541152954101562
# Contrastive Epoch 23, Loss: 0.520119309425354
# Contrastive Epoch 24, Loss: 0.4958329200744629
# Contrastive Epoch 25, Loss: 0.485571026802063
# Contrastive Epoch 26, Loss: 0.4700872302055359
# Contrastive Epoch 27, Loss: 0.46838343143463135
# Contrastive Epoch 28, Loss: 0.4476989507675171
# Contrastive Epoch 29, Loss: 0.42271602153778076
# Contrastive Epoch 30, Loss: 0.39710670709609985
# Contrastive Epoch 31, Loss: 0.3784400224685669
# Contrastive Epoch 32, Loss: 0.3622429072856903
# Contrastive Epoch 33, Loss: 0.34081146121025085
# Contrastive Epoch 34, Loss: 0.33305037021636963
# Contrastive Epoch 35, Loss: 0.32324451208114624
# Contrastive Epoch 36, Loss: 0.31683045625686646
# Contrastive Epoch 37, Loss: 0.31137382984161377
# Contrastive Epoch 38, Loss: 0.30475184321403503
# Contrastive Epoch 39, Loss: 0.2969757616519928
# Contrastive Epoch 40, Loss: 0.30001240968704224
# Contrastive Epoch 41, Loss: 0.2948229908943176
# Contrastive Epoch 42, Loss: 0.290801078081131
# Contrastive Epoch 43, Loss: 0.2881013751029968
# Contrastive Epoch 44, Loss: 0.2844083309173584
# Contrastive Epoch 45, Loss: 0.284503698348999
# Contrastive Epoch 46, Loss: 0.282554566860199
# Contrastive Epoch 47, Loss: 0.28245583176612854
# Contrastive Epoch 48, Loss: 0.28422343730926514
# Contrastive Epoch 49, Loss: 0.28613749146461487
# Contrastive Epoch 50, Loss: 0.2925766706466675
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step
# Epoch 1/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - accuracy: 0.4352 - loss: 1.2302 - val_accuracy: 0.4610 - val_loss: 0.9736
# Epoch 2/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.5655 - loss: 0.8961 - val_accuracy: 0.6317 - val_loss: 0.8779
# Epoch 3/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - accuracy: 0.6506 - loss: 0.8255 - val_accuracy: 0.6463 - val_loss: 0.8262
# Epoch 4/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 51ms/step - accuracy: 0.6798 - loss: 0.7685 - val_accuracy: 0.6146 - val_loss: 0.8374
# Epoch 5/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.6178 - loss: 0.7716 - val_accuracy: 0.6146 - val_loss: 0.8405
# Epoch 6/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - accuracy: 0.6589 - loss: 0.7628 - val_accuracy: 0.6463 - val_loss: 0.7847
# Epoch 7/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.6831 - loss: 0.7384 - val_accuracy: 0.6268 - val_loss: 0.7741
# Epoch 8/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - accuracy: 0.6883 - loss: 0.7215 - val_accuracy: 0.5415 - val_loss: 0.8567
# Epoch 9/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - accuracy: 0.6259 - loss: 0.7665 - val_accuracy: 0.6512 - val_loss: 0.7541
# Epoch 10/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - accuracy: 0.6992 - loss: 0.7141 - val_accuracy: 0.6488 - val_loss: 0.7541
# Epoch 11/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 0.6894 - loss: 0.6906 - val_accuracy: 0.6683 - val_loss: 0.7263
# Epoch 12/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 0.6962 - loss: 0.6999 - val_accuracy: 0.6756 - val_loss: 0.7290
# Epoch 13/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - accuracy: 0.7274 - loss: 0.6604 - val_accuracy: 0.6902 - val_loss: 0.6980
# Epoch 14/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - accuracy: 0.7311 - loss: 0.6640 - val_accuracy: 0.6805 - val_loss: 0.6988
# Epoch 15/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - accuracy: 0.7461 - loss: 0.6014 - val_accuracy: 0.6829 - val_loss: 0.6906
# Epoch 16/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.7644 - loss: 0.5947 - val_accuracy: 0.7171 - val_loss: 0.6318
# Epoch 17/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.7499 - loss: 0.6177 - val_accuracy: 0.7268 - val_loss: 0.6085
# Epoch 18/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 0.7916 - loss: 0.5607 - val_accuracy: 0.7366 - val_loss: 0.5989
# Epoch 19/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - accuracy: 0.7747 - loss: 0.5525 - val_accuracy: 0.7732 - val_loss: 0.5693
# Epoch 20/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - accuracy: 0.8078 - loss: 0.5179 - val_accuracy: 0.7220 - val_loss: 0.5866
# Epoch 21/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.7820 - loss: 0.5365 - val_accuracy: 0.7390 - val_loss: 0.5941
# Epoch 22/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.8172 - loss: 0.5014 - val_accuracy: 0.7854 - val_loss: 0.5432
# Epoch 23/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.8144 - loss: 0.4824 - val_accuracy: 0.8098 - val_loss: 0.5053
# Epoch 24/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 0.8219 - loss: 0.4783 - val_accuracy: 0.7512 - val_loss: 0.5555
# Epoch 25/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.8344 - loss: 0.4537 - val_accuracy: 0.7683 - val_loss: 0.5207
# Epoch 26/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.7943 - loss: 0.4738 - val_accuracy: 0.8268 - val_loss: 0.4538
# Epoch 27/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - accuracy: 0.8269 - loss: 0.4554 - val_accuracy: 0.8024 - val_loss: 0.4754
# Epoch 28/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.8428 - loss: 0.4239 - val_accuracy: 0.7976 - val_loss: 0.4758
# Epoch 29/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - accuracy: 0.8482 - loss: 0.4164 - val_accuracy: 0.8341 - val_loss: 0.4536
# Epoch 30/30
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - accuracy: 0.8238 - loss: 0.4155 - val_accuracy: 0.8122 - val_loss: 0.4462
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8262 - loss: 0.7034
# Pseudo-Test Accuracy: 0.818359375

# %%
import pickle

# Assuming `model` is your trained machine learning model
with open('contrastive_new.pkl', 'wb') as file:
    pickle.dump(Contrastive, file)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 5
#       3 # Assuming `model` is your trained machine learning model
#       4 with open('contrastive_new.pkl', 'wb') as file:
# ----> 5     pickle.dump(Contrastive, file)
#
# NameError: name 'Contrastive' is not defined
